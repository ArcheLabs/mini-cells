# %% [markdown]
# # Core Validation 009B-3 — Deployable Effect Addressability
#
# Run cells in order **only after Core 009B-2 is formally positive**. Each stage commits its lock before the next stage.

# %%
import pathlib, shutil, subprocess
ROOT = pathlib.Path('/kaggle/working/mini-cells')
BRANCH = 'codex/core-validation-009b3-deployable-effect-addressability'
shutil.rmtree(ROOT, ignore_errors=True)
subprocess.run(['git','clone','--depth','1','--branch',BRANCH,'https://github.com/ArcheLabs/mini-cells.git',str(ROOT)], check=True)
subprocess.run(['python','-m','pip','install','-q','-e','.[lm]'], cwd=ROOT, check=True)
subprocess.run(['python','scripts/research/prepare_core_validation_009b3_parent.py','--branch',BRANCH,'--push-results'], cwd=ROOT, check=True)

# %%
# Discovery: run from a fresh checkout containing committed parent-lock.json.
import pathlib, shutil, subprocess
ROOT = pathlib.Path('/kaggle/working/mini-cells')
BRANCH = 'codex/core-validation-009b3-deployable-effect-addressability'
shutil.rmtree(ROOT, ignore_errors=True)
subprocess.run(['git','clone','--depth','1','--branch',BRANCH,'https://github.com/ArcheLabs/mini-cells.git',str(ROOT)], check=True)
subprocess.run(['python','-m','pip','install','-q','-e','.[lm]'], cwd=ROOT, check=True)
subprocess.run(['python','scripts/research/orchestrate_core_validation_009b3.py','--phase','discovery','--branch',BRANCH,'--device','cuda','--push-results'], cwd=ROOT, check=True)

# %%
# Confirmation: run only if discovery published confirmation_allowed=true and router-lock.json.
import pathlib, shutil, subprocess
ROOT = pathlib.Path('/kaggle/working/mini-cells')
BRANCH = 'codex/core-validation-009b3-deployable-effect-addressability'
shutil.rmtree(ROOT, ignore_errors=True)
subprocess.run(['git','clone','--depth','1','--branch',BRANCH,'https://github.com/ArcheLabs/mini-cells.git',str(ROOT)], check=True)
subprocess.run(['python','-m','pip','install','-q','-e','.[lm]'], cwd=ROOT, check=True)
subprocess.run(['python','scripts/research/orchestrate_core_validation_009b3.py','--phase','confirmation','--branch',BRANCH,'--device','cuda','--push-results'], cwd=ROOT, check=True)
