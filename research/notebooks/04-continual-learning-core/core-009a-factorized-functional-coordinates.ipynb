# %% [markdown]
# # Core Validation 009A — Factorized Functional Coordinates
#
# Run **Discovery** first. Confirmation must only be run from a checkout that already contains the published `winner-lock.json`. Use Kaggle GPU + Internet and the `GITHUB_TOKEN` secret.

# %%
import os, subprocess, pathlib
ROOT = pathlib.Path('/kaggle/working/mini-cells')
BRANCH = 'codex/core-validation-009a-factorized-functional-coordinates'
if not ROOT.exists():
    subprocess.run(['git','clone','--branch',BRANCH,'https://github.com/ArcheLabs/mini-cells.git',str(ROOT)], check=True)
else:
    subprocess.run(['git','fetch','origin',BRANCH], cwd=ROOT, check=True)
    subprocess.run(['git','checkout',BRANCH], cwd=ROOT, check=True)
    subprocess.run(['git','pull','--ff-only','origin',BRANCH], cwd=ROOT, check=True)
subprocess.run(['python','-m','pip','install','-e','.'], cwd=ROOT, check=True)
subprocess.run(['python','scripts/research/orchestrate_core_validation_009a.py','--phase','discovery','--branch',BRANCH,'--device','cuda','--push-results'], cwd=ROOT, check=True)

# %% [markdown]
# ## Confirmation
#
# Do **not** run this cell unless discovery completed, reported `confirmation_allowed=true`, and the branch has been refreshed so `research/validations/core-009a-factorized-functional-coordinates/winner-lock.json` exists.

# %%
import subprocess, pathlib
ROOT = pathlib.Path('/kaggle/working/mini-cells')
BRANCH = 'codex/core-validation-009a-factorized-functional-coordinates'
subprocess.run(['git','fetch','origin',BRANCH], cwd=ROOT, check=True)
subprocess.run(['git','checkout',BRANCH], cwd=ROOT, check=True)
subprocess.run(['git','pull','--ff-only','origin',BRANCH], cwd=ROOT, check=True)
lock = ROOT / 'research/validations/core-009a-factorized-functional-coordinates/winner-lock.json'
assert lock.is_file(), 'winner-lock.json missing; confirmation is forbidden'
subprocess.run(['python','scripts/research/orchestrate_core_validation_009a.py','--phase','confirmation','--branch',BRANCH,'--device','cuda','--push-results'], cwd=ROOT, check=True)
