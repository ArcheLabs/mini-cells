# %% [markdown]
# # Core Validation 009A Bridge — Right-Side Collapse Robustness
#
# Post-confirmation diagnostic only. Requires Kaggle GPU + Internet and a `GITHUB_TOKEN` secret. The source 009A decision remains immutable.

# %%
import json, pathlib, shutil, subprocess
ROOT = pathlib.Path('/kaggle/working/mini-cells')
BRANCH = 'codex/core-validation-009a-right-collapse-bridge'
shutil.rmtree(ROOT, ignore_errors=True)
subprocess.run(['git','clone','--depth','1','--branch',BRANCH,'https://github.com/ArcheLabs/mini-cells.git',str(ROOT)], check=True)
subprocess.run(['python','-m','pip','install','-q','-e','.[lm]'], cwd=ROOT, check=True)
subprocess.run(['python','scripts/research/orchestrate_core_validation_009a_bridge.py','--branch',BRANCH,'--device','cuda','--push-results'], cwd=ROOT, check=True)
decision = json.loads((ROOT / 'results/core-validation-009a-right-collapse-bridge/decision.json').read_text())
print(json.dumps(decision, indent=2, sort_keys=True))
print((ROOT / 'results/core-validation-009a-right-collapse-bridge/RESULTS.md').read_text())
