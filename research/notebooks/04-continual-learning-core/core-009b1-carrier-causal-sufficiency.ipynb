# %% [markdown]
# # Core Validation 009B-1 — Carrier Causal Sufficiency
#
# Run Discovery first. Confirmation is forbidden until discovery publishes a committed `scale-lock.json`. Requires Kaggle GPU + Internet and `GITHUB_TOKEN`; `HF_TOKEN` is optional.

# %%
import json, pathlib, shutil, subprocess
ROOT = pathlib.Path('/kaggle/working/mini-cells')
BRANCH = 'codex/core-validation-009b1-carrier-causal-sufficiency'
shutil.rmtree(ROOT, ignore_errors=True)
subprocess.run(['git','clone','--depth','1','--branch',BRANCH,'https://github.com/ArcheLabs/mini-cells.git',str(ROOT)], check=True)
subprocess.run(['python','-m','pip','install','-q','-e','.[lm]'], cwd=ROOT, check=True)
subprocess.run(['python','scripts/research/orchestrate_core_validation_009b1.py','--phase','discovery','--branch',BRANCH,'--device','cuda','--push-results'], cwd=ROOT, check=True)
decision = json.loads((ROOT/'results/core-validation-009b1-carrier-causal-sufficiency/discovery/decision.json').read_text())
print(json.dumps(decision, indent=2, sort_keys=True))

# %% [markdown]
# ## Confirmation
#
# Run only after Discovery reports `confirmation_allowed=true`, publishes `scale-lock.json`, and you refresh/reclone the branch.

# %%
import json, pathlib, shutil, subprocess
ROOT = pathlib.Path('/kaggle/working/mini-cells')
BRANCH = 'codex/core-validation-009b1-carrier-causal-sufficiency'
shutil.rmtree(ROOT, ignore_errors=True)
subprocess.run(['git','clone','--depth','1','--branch',BRANCH,'https://github.com/ArcheLabs/mini-cells.git',str(ROOT)], check=True)
lock = ROOT/'research/validations/core-009b1-carrier-causal-sufficiency/scale-lock.json'
assert lock.is_file(), 'scale-lock.json missing; confirmation is forbidden'
subprocess.run(['python','-m','pip','install','-q','-e','.[lm]'], cwd=ROOT, check=True)
subprocess.run(['python','scripts/research/orchestrate_core_validation_009b1.py','--phase','confirmation','--branch',BRANCH,'--device','cuda','--push-results'], cwd=ROOT, check=True)
decision = json.loads((ROOT/'results/core-validation-009b1-carrier-causal-sufficiency/confirmation/decision.json').read_text())
print(json.dumps(decision, indent=2, sort_keys=True))
print((ROOT/'results/core-validation-009b1-carrier-causal-sufficiency/confirmation/RESULTS.md').read_text())
