# %% [markdown]
# # Core Validation 005 — Replay-Free Subspace-Certified Mitosis
#
# Single frozen CPU formal run. No calibration and no learner-side replay.

# %%
from pathlib import Path
ROOT = Path.cwd()
print(ROOT)

# %%
# !python scripts/research/run_core_validation_005.py --device cpu

# %%
# !python scripts/research/report_core_validation_005.py

# %%
import json
decision = json.loads(Path('results/core-validation-005-subspace-certified-mitosis/decision.json').read_text())
decision
